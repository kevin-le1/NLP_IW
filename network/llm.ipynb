# %%
from langchain_ollama.llms import OllamaLLM
from scapy.all import rdpcap, Raw
from scapy.layers.http import HTTPRequest, HTTPResponse
from scapy.layers.dns import DNSQR, DNSRR
import os

# Function to extract HTTP and DNS data
def extract_data_from_packets(packets):
    extracted_data = []
    for packet in packets:
        # HTTP Request
        if packet.haslayer(HTTPRequest):
            http_layer = packet[HTTPRequest]
            extracted_data.append({
                "type": "HTTP Request",
                "method": http_layer.Method.decode() if http_layer.Method else "",
                "host": http_layer.Host.decode() if http_layer.Host else "",
                "path": http_layer.Path.decode() if http_layer.Path else "",
            })
            
        # HTTP Response
        elif packet.haslayer(HTTPResponse):
            http_layer = packet[HTTPResponse]
            extracted_data.append({
                "type": "HTTP Response",
                "status_code": http_layer.Status_Code.decode() if http_layer.Status_Code else "",
                "reason": http_layer.Reason_Phrase.decode() if http_layer.Reason_Phrase else "",
            })
            
        # DNS Query
        elif packet.haslayer(DNSQR):
            dns_layer = packet[DNSQR]
            extracted_data.append({
                "type": "DNS Query",
                "query_name": dns_layer.qname.decode() if dns_layer.qname else "",
            })
            
        # DNS Response
        elif packet.haslayer(DNSRR):
            dns_layer = packet[DNSRR]
            extracted_data.append({
                "type": "DNS Response",
                "response_name": dns_layer.rrname.decode() if dns_layer.rrname else "",
                "response_data": dns_layer.rdata.decode() if hasattr(dns_layer.rdata, "decode") else dns_layer.rdata,
            })
            
    return extracted_data

# Function to batch the data
def batch_data(data, batch_size):
    for i in range(0, len(data), batch_size):
        yield data[i:i + batch_size]
        
# Function to process each batch for an LLM
def prepare_batch_for_llm(batch):
    llm_input = ""
    for item in batch:
        if item["type"] == "HTTP Request":
            llm_input += f"HTTP Request - Method: {item['method']}, Host: {item['host']}, Path: {item['path']}\n"
        elif item["type"] == "HTTP Response":
            llm_input += f"HTTP Response - Status Code: {item['status_code']}, Reason: {item['reason']}\n"
        elif item["type"] == "DNS Query":
            llm_input += f"DNS Query - Query Name: {item['query_name']}\n"
        elif item["type"] == "DNS Response":
            llm_input += f"DNS Response - Response Name: {item['response_name']}, Response Data: {item['response_data']}\n"
    return llm_input

# Function to query LLM for each batch
def analyze_batch_with_llm(llm, batch_input):
    prompt = f"""
You are a cybersecurity expert. Analyze the following network packet data for any suspicious activities and identify any malicious elements. If you cannot detect any malicious elements then say "I cannot detect any malicious elements":

{batch_input}

Is there anything suspicious? If so, describe the malicious activity in detail.
"""
    response = llm.generate(prompts=[prompt])
    return response


def run(packets):
    # Define the number of batches (5)
    NUM_BATCHES = 5

    # Extract data from the PCAP file
    data = extract_data_from_packets(packets)

    # Calculate the number of packets in each batch
    total_packets = len(data)
    batch_size = total_packets // NUM_BATCHES  # Base size of each batch
    remainder = total_packets % NUM_BATCHES   # Remaining packets to distribute

    # Prepare the batches
    all_batches = []
    start_idx = 0

    for i in range(NUM_BATCHES):
        # Calculate the size of this batch (base size + 1 if remainder > 0)
        end_idx = start_idx + batch_size + (1 if i < remainder else 0)
        batch = data[start_idx:end_idx]
        all_batches.append(batch)

        # Update the starting index for the next batch
        start_idx = end_idx

    # Initialize LLM
    llm = OllamaLLM(model="llama3.1:latest", max_tokens=4000, temperature=0.2)

    # Analyze all batches
    results = []
    for i, batch in enumerate(all_batches):
        
        print(batch)
        print(f"Analyzing batch {i + 1}/{len(all_batches)}...")
        result = analyze_batch_with_llm(llm, batch)
        print(result)
        results.append({"batch": i + 1, "response": result})

    # Print results for each batch
    # for result in results:
    #     print(f"Analysis:\n{result['response']['generations'][0]['text']}\n")

    return results

# %%
results = run(rdpcap("/Users/kevin/Desktop/NLP_IW/network/packet_inject/hao123-com_packet-injection.pcap"))
# Out:
# [{'type': 'HTTP Request', 'method': 'GET', 'host': 'www.02995.com', 'path': '/'}, {'type': 'HTTP Response', 'status_code': '302', 'reason': 'Moved Temporarily'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/?tn=93803173_s_hao_pg'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}]
# Analyzing batch 1/5...
# generations=[[GenerationChunk(text="After analyzing the network packet data, I have identified a potential malicious element.\n\nThe suspicious activity is related to the second HTTP request:\n\n`{'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/?tn=93803173_s_hao_pg'}`\n\nThis URL appears to be a redirect URL, which is a common technique used by attackers to bypass security controls. The `tn` parameter in the URL seems to be a tracking number or a token that might be used for malicious purposes.\n\nUpon further investigation, I found that `www.hao123.com` is a Chinese website that has been associated with malware and phishing attacks in the past. This raises concerns about the legitimacy of the redirect URL.\n\nThe fact that this request was made after a 302 status code (Moved Temporarily) from `www.02995.com` suggests that there might be a chain of redirects, which can be used to conceal the true destination of the request. This could potentially lead to a malicious website or malware being downloaded onto the victim's device.\n\nAdditionally, the presence of a tracking number (`tn=93803173_s_hao_pg`) in the URL could indicate that the attacker is trying to track user activity or steal sensitive information.\n\nIn summary, while I cannot confirm with certainty whether this activity is malicious without further context, the combination of suspicious URL parameters and redirects from an unknown website raises significant concerns about potential malicious activity.", generation_info={'model': 'llama3.1:latest', 'created_at': '2024-12-07T19:28:32.999793Z', 'response': '', 'done': True, 'done_reason': 'stop', 'context': [128006, 882, 128007, 1432, 2675, 527, 264, 62542, 6335, 13, 38527, 3059, 279, 2768, 4009, 10361, 828, 369, 904, 32427, 7640, 323, 10765, 904, 39270, 5540, 13, 1442, 499, 4250, 11388, 904, 39270, 5540, 1243, 2019, 330, 40, 4250, 11388, 904, 39270, 5540, 52518, 58, 13922, 1337, 1232, 364, 9412, 6274, 518, 364, 4492, 1232, 364, 3891, 518, 364, 3875, 1232, 364, 2185, 13, 23273, 2721, 916, 518, 364, 2398, 1232, 15198, 2186, 5473, 1337, 1232, 364, 9412, 6075, 518, 364, 2899, 4229, 1232, 364, 13121, 518, 364, 20489, 1232, 364, 54332, 20539, 97254, 25762, 5473, 1337, 1232, 364, 9412, 6274, 518, 364, 4492, 1232, 364, 3891, 518, 364, 3875, 1232, 364, 2185, 870, 3524, 4513, 916, 518, 364, 2398, 1232, 3434, 30, 1546, 28, 25454, 18887, 5958, 646, 1552, 3524, 59781, 25762, 5473, 1337, 1232, 364, 9412, 6075, 518, 364, 2899, 4229, 1232, 364, 1049, 518, 364, 20489, 1232, 364, 4012, 25762, 5473, 1337, 1232, 364, 9412, 6075, 518, 364, 2899, 4229, 1232, 364, 1049, 518, 364, 20489, 1232, 364, 4012, 8439, 2595, 3957, 1070, 4205, 32427, 30, 1442, 779, 11, 7664, 279, 39270, 5820, 304, 7872, 627, 128009, 128006, 78191, 128007, 271, 6153, 42118, 279, 4009, 10361, 828, 11, 358, 617, 11054, 264, 4754, 39270, 2449, 382, 791, 32427, 5820, 374, 5552, 311, 279, 2132, 10339, 1715, 1473, 63, 13922, 1337, 1232, 364, 9412, 6274, 518, 364, 4492, 1232, 364, 3891, 518, 364, 3875, 1232, 364, 2185, 870, 3524, 4513, 916, 518, 364, 2398, 1232, 3434, 30, 1546, 28, 25454, 18887, 5958, 646, 1552, 3524, 59781, 6, 5658, 271, 2028, 5665, 8111, 311, 387, 264, 6559, 5665, 11, 902, 374, 264, 4279, 15105, 1511, 555, 42065, 311, 31818, 4868, 11835, 13, 578, 1595, 1546, 63, 5852, 304, 279, 5665, 5084, 311, 387, 264, 15194, 1396, 477, 264, 4037, 430, 2643, 387, 1511, 369, 39270, 10096, 382, 50384, 4726, 8990, 11, 358, 1766, 430, 1595, 2185, 870, 3524, 4513, 916, 63, 374, 264, 8620, 3997, 430, 706, 1027, 5938, 449, 40831, 323, 99197, 8951, 304, 279, 3347, 13, 1115, 25930, 10742, 922, 279, 57008, 315, 279, 6559, 5665, 382, 791, 2144, 430, 420, 1715, 574, 1903, 1306, 264, 220, 13121, 2704, 2082, 320, 54332, 20539, 97254, 8, 505, 1595, 2185, 13, 23273, 2721, 916, 63, 13533, 430, 1070, 2643, 387, 264, 8957, 315, 72271, 11, 902, 649, 387, 1511, 311, 54262, 279, 837, 9284, 315, 279, 1715, 13, 1115, 1436, 13893, 3063, 311, 264, 39270, 3997, 477, 4 ...
# [{'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/api/tnwhilte?tn=93803173_s_hao_pg&_=1456819436683'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/v.gif?e=AB0_ce01018c62dced37ae0916c9ffb6eff0_0_0_7mgeu6&_=il94ofz1'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/images/track.gif?level=1&page=index&type=ua&browser=firefox_41&core=firefox_41&device=na_-1&os=linux_-1&r=1456819438383'}]
# Analyzing batch 2/5...
# generations=[[GenerationChunk(text="After analyzing the network packet data, I have identified some suspicious activities. Here's a detailed breakdown:\n\n**Malicious Activity 1: Unusual URL Parameters**\n\nThe first HTTP request to `www.hao123.com` contains an unusual parameter `tn=93803173_s_hao_pg&_=1456819436683`. The presence of this parameter is suspicious because it appears to be a tracking or analytics token, which is not typically included in a standard GET request. This could indicate that the website is using some form of tracking or monitoring mechanism without user consent.\n\n**Malicious Activity 2: Image Request with Suspicious Parameters**\n\nThe third HTTP request to `www.hao123.com` contains an image request (`/images/track.gif`) with several suspicious parameters:\n\n* `level=1`: This parameter suggests that the website is using some form of tracking or monitoring mechanism, which could be used to collect user data.\n* `page=index&type=ua&browser=firefox_41&core=firefox_41&device=na_-1&os=linux_-1&r=1456819438383`: These parameters appear to be collecting information about the user's browser, operating system, and device. This could be used for tracking or profiling purposes.\n\n**Malicious Activity 3: Unusual Image Request**\n\nThe second HTTP request to `www.hao123.com` contains an image request (`/v.gif`) with a suspicious parameter `e=AB0_ce01018c62dced37ae0916c9ffb6eff0_0_0_7mgeu6&_=il94ofz1`. The presence of this parameter is unusual and could indicate that the website is using some form of tracking or monitoring mechanism.\n\n**Conclusion**\n\nBased on my analysis, I have identified three suspicious activities:\n\n1. Unusual URL parameters in the first HTTP request.\n2. Image requests with suspicious parameters (tracking/monitoring tokens) in the second and third HTTP requests.\n3. An unusual image request with a suspicious parameter.\n\nThese activities could indicate that the website is using some form of tracking or monitoring mechanism without user consent, which raises concerns about user privacy. However, it's essential to note that these findings do not necessarily mean that the website is malicious or intentionally collecting sensitive information. Further investigation and analysis would be required to determine the true nature of these activities.", generation_info={'model': 'llama3.1:latest', 'created_at': '2024-12-07T19:29:03.565853Z', 'response': '', 'done': True, 'done_reason': 'stop', 'context': [128006, 882, 128007, 1432, 2675, 527, 264, 62542, 6335, 13, 38527, 3059, 279, 2768, 4009, 10361, 828, 369, 904, 32427, 7640, 323, 10765, 904, 39270, 5540, 13, 1442, 499, 4250, 11388, 904, 39270, 5540, 1243, 2019, 330, 40, 4250, 11388, 904, 39270, 5540, 52518, 58, 13922, 1337, 1232, 364, 9412, 6274, 518, 364, 4492, 1232, 364, 3891, 518, 364, 3875, 1232, 364, 2185, 870, 3524, 4513, 916, 518, 364, 2398, 1232, 3434, 2113, 14, 1546, 1336, 321, 668, 30, 1546, 28, 25454, 18887, 5958, 646, 1552, 3524, 59781, 5, 47185, 9591, 25091, 26576, 24427, 18, 25762, 5473, 1337, 1232, 364, 9412, 6075, 518, 364, 2899, 4229, 1232, 364, 1049, 518, 364, 20489, 1232, 364, 4012, 25762, 5473, 1337, 1232, 364, 9412, 6274, 518, 364, 4492, 1232, 364, 3891, 518, 364, 3875, 1232, 364, 2185, 870, 3524, 4513, 916, 518, 364, 2398, 1232, 3434, 85, 16391, 30, 68, 28, 1905, 15, 51827, 7755, 972, 66, 5538, 67, 2041, 1806, 6043, 24443, 21, 66, 24, 89649, 21, 6581, 15, 62, 15, 62, 15, 62, 22, 76, 713, 84, 21, 5, 47185, 321, 6281, 1073, 89, 16, 25762, 5473, 1337, 1232, 364, 9412, 6075, 518, 364, 2899, 4229, 1232, 364, 1049, 518, 364, 20489, 1232, 364, 4012, 25762, 5473, 1337, 1232, 364, 9412, 6274, 518, 364, 4492, 1232, 364, 3891, 518, 364, 3875, 1232, 364, 2185, 870, 3524, 4513, 916, 518, 364, 2398, 1232, 3434, 3726, 14, 13432, 16391, 30, 3374, 28, 16, 75610, 63741, 69941, 28, 4381, 5, 23279, 28, 99012, 62, 3174, 5, 2202, 28, 99012, 62, 3174, 5, 6239, 28, 3458, 40411, 16, 5, 437, 28, 14544, 40411, 16, 61717, 28, 9591, 25091, 26576, 24 ...
# [{'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/api/newforecast?callback=jQuery17207509154191061225_1456819436527&t=1&_=1456819438720'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/images/track.gif?level=1&page=index&type=KTN&code=0&tn=&src=&r=1456819439201'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}]
# Analyzing batch 3/5...
# generations=[[GenerationChunk(text="After analyzing the network packet data, I have detected some suspicious activities. Here's a detailed description of the malicious elements:\n\n**Malicious Activity 1: Unusual HTTP Request**\n\nThe first GET request to `www.hao123.com/api/newforecast` contains a callback parameter with a jQuery-specific callback function (`jQuery17207509154191061225_1456819436527`). This is unusual because it suggests that the client-side JavaScript code is making an AJAX request to this API endpoint, which may be used for tracking or analytics purposes. However, the presence of this callback parameter could also indicate that a malicious script is being executed on the client-side.\n\n**Malicious Activity 2: Tracking GIF Request**\n\nThe second GET request to `www.hao123.com/images/track.gif` contains several parameters (`level=1`, `page=index`, `type=KTN`, `code=0`, `tn=&src=&r=1456819439201`) that seem unrelated to the actual content of the track GIF image. These parameters may be used for tracking or analytics purposes, but they could also be used by a malicious script to fingerprint the user's browser or device.\n\n**Malicious Activity 3: Unusual Timing**\n\nThe timing between the two GET requests is extremely short (approximately 1 millisecond), which suggests that these requests are being made in rapid succession. This unusual timing pattern may indicate that a malicious script is trying to evade detection by making multiple requests in quick succession.\n\nIn summary, while I cannot confirm with certainty whether these activities are malicious or not, the presence of unusual callback parameters, tracking GIF requests, and suspicious timing patterns suggest that there may be some malicious activity occurring. Further analysis would be required to determine the full extent of this potential threat.", generation_info={'model': 'llama3.1:latest', 'created_at': '2024-12-07T19:29:25.817997Z', 'response': '', 'done': True, 'done_reason': 'stop', 'context': [128006, 882, 128007, 1432, 2675, 527, 264, 62542, 6335, 13, 38527, 3059, 279, 2768, 4009, 10361, 828, 369, 904, 32427, 7640, 323, 10765, 904, 39270, 5540, 13, 1442, 499, 4250, 11388, 904, 39270, 5540, 1243, 2019, 330, 40, 4250, 11388, 904, 39270, 5540, 52518, 58, 13922, 1337, 1232, 364, 9412, 6075, 518, 364, 2899, 4229, 1232, 364, 1049, 518, 364, 20489, 1232, 364, 4012, 25762, 5473, 1337, 1232, 364, 9412, 6274, 518, 364, 4492, 1232, 364, 3891, 518, 364, 3875, 1232, 364, 2185, 870, 3524, 4513, 916, 518, 364, 2398, 1232, 3434, 2113, 26448, 60084, 30, 13802, 28, 29104, 10861, 22679, 24443, 22058, 21056, 21018, 914, 62, 9591, 25091, 26576, 23181, 22, 64325, 28, 16, 5, 47185, 9591, 25091, 26576, 25303, 15, 25762, 5473, 1337, 1232, 364, 9412, 6075, 518, 364, 2899, 4229, 1232, 364, 1049, 518, 364, 20489, 1232, 364, 4012, 25762, 5473, 1337, 1232, 364, 9412, 6274, 518, 364, 4492, 1232, 364, 3891, 518, 364, 3875, 1232, 364, 2185, 870, 3524, 4513, 916, 518, 364, 2398, 1232, 3434, 3726, 14, 13432, 16391, 30, 3374, 28, 16, 75610, 63741, 69941, 28, 42, 30271, 5, 1889, 28, 15, 5, 1546, 26423, 3632, 26423, 81, 28, 9591, 25091, 26576, 18485, 16, 25762, 5473, 1337, 1232, 364, 9412, 6075, 518, 364, 2899, 4229, 1232, 364, 1049, 518, 364, 20489, 1232, 364, 4012, 8439, 2595, 3957, 1070, 4205, 32427, 30, 1442, 779, 11, 7664, 279, 39270, 5820, 304, 7872, 627, 128009, 128006, 78191, 128007, 271, 6153, 42118, 279, 4009, 10361, 828, 11, 358, 617, 16914, 1063, 32427, 7640, 13, 5810, 596, 264, 11944, 4096, 315, 279, 39270, 5540, 1473, 334, 30700, 9824, 15330, 220, 16, 25, 1252, 81324, 10339, 6274, 57277, 791, 1176, 8049, 1715, 311, 1595, 2185, 870, 3524, 4513, 916, 10729, 26448, 60084, 63, 5727, 264, 4927, 5852, 449, 264, 13518, 19440, 4927, 734, 29754, 29104, 10861, 22679, 24443, 22058, 21056, 21018, 914, 62, 9591, 25091, 26576, 23181, 22, 60310, 1115, 374, 19018, 1606, 433, 13533, 430, 279, 3016, 25034, 13210, 2082, 374, 3339, 459, 58416, 1715, 311, 420, 5446, 15233, 11, 902, 125 ...
# [{'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/v.gif?c=f%2Cf503a8d7.PHubPHwWuW0znjNbnWRYuHI9P1-WmH79xjDYPHm3nHbYPjKtxjT4QWDsnB3zPjb8n1Ktn1-trjbYxAPYT-qk5HTsnakWTAdxTHYknakWIZFxIZFb5HnsQANzpgP-u7qVUvwdUARqnBkEIgw-T-q-XZKxIA7M5iktQH7xQH7xQH7xQH7xQHDoQH7xgdqxgdqxgdqxgdqxgdqxgdqtrHn3njnkP1PxTdqCmyqxTAT%3APjc4P1DYxjcsnZsknjKtnWD4xj0&flag=hao123-cpc'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/images/track.gif?level=1&page=index&type=cpc&state=-1&bid=5B7AB1B70A3EEB48F7B3BE4B62FBFDB8&code=cpc_gl_gouwu0&r=1456819441081'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}]
# Analyzing batch 4/5...
# generations=[[GenerationChunk(text='After analyzing the network packet data, I have detected a potential malicious activity. Here\'s my analysis:\n\n**Suspicious Activity:**\n\nThe first HTTP request to `www.hao123.com` contains a query string parameter called `flag=hao123-cpc`. This parameter is not typical of a standard HTTP request and may indicate an attempt to track or fingerprint the user.\n\nFurthermore, the second HTTP request to `www.hao123.com` contains several suspicious parameters:\n\n* `/images/track.gif?level=1&page=index&type=cpc&state=-1&bid=5B7AB1B70A3EEB48F7B3BE4B62FBFDB8&code=cpc_gl_gouwu0&r=1456819441081`\n\nThese parameters suggest that the request is attempting to track or monitor user activity, possibly for advertising or analytics purposes. The presence of a unique identifier (`bid`) and a timestamp (`r`) further supports this theory.\n\n**Malicious Elements:**\n\nWhile not necessarily malicious in nature, these activities could be considered suspicious or unwanted tracking behavior. The use of query string parameters to track user activity is often associated with online advertising or analytics scripts that may compromise user privacy.\n\nIn the context of cybersecurity, this activity could be classified as a "tracking" or "fingerprinting" attack, where an attacker attempts to gather information about a user\'s browsing habits without their consent. However, it\'s essential to note that this behavior is not necessarily malicious in intent but rather a form of unwanted tracking.\n\n**Recommendation:**\n\nTo mitigate this potential issue, users should be aware of the websites they visit and the data they share online. They can also use browser extensions or tools to block or disable tracking scripts like these. Additionally, website administrators should ensure that their websites do not inadvertently enable tracking behavior by including suspicious query string parameters in their HTTP requests.\n\n**Conclusion:**\n\nWhile I have detected a potential malicious activity, it\'s essential to note that this behavior is more related to unwanted tracking than an actual cyber attack. However, users and website administrators should remain vigilant and take necessary precautions to protect user privacy and security.', generation_info={'model': 'llama3.1:latest', 'created_at': '2024-12-07T19:29:54.796677Z', 'response': '', 'done': True, 'done_reason': 'stop', 'context': [128006, 882, 128007, 1432, 2675, 527, 264, 62542, 6335, 13, 38527, 3059, 279, 2768, 4009, 10361, 828, 369, 904, 32427, 7640, 323, 10765, 904, 39270, 5540, 13, 1442, 499, 4250, 11388, 904, 39270, 5540, 1243, 2019, 330, 40, 4250, 11388, 904, 39270, 5540, 52518, 58, 13922, 1337, 1232, 364, 9412, 6274, 518, 364, 4492, 1232, 364, 3891, 518, 364, 3875, 1232, 364, 2185, 870, 3524, 4513, 916, 518, 364, 2398, 1232, 3434, 85, 16391, 30, 66, 18603, 4, 17, 34, 69, 17735, 64, 23, 67, 22, 1087, 19876, 11079, 86, 54, 84, 54, 15, 20926, 73, 45, 11328, 54, 11492, 84, 24860, 24, 47, 16, 13299, 76, 39, 4643, 87, 73, 35, 10158, 39, 76, 18, 77, 39, 65, 10158, 73, 42, 4086, 73, 51, 19, 48, 18023, 9810, 33, 18, 89, 47, 40078, 23, 77, 16, 42, 1546, 16, 10398, 40078, 56, 87, 2599, 79445, 52708, 74, 20, 2607, 9810, 587, 18961, 2654, 87, 3701, 56, 19639, 587, 54, 2913, 82956, 2913, 37, 65, 20, 39, 4511, 48, 1111, 89, 3601, 47, 46481, 22, 80, 53, 52, 85, 6511, 52, 946, 49450, 33, 74, 79882, 55233, 9469, 52708, 31650, 57, 42, 87, 5987, 22, 44, 20, 32680, 48, 39, 22, 87, 48, 39, 22, 87, 48, 39, 22, 87, 48, 39, 22, 87, 48, 39, 5519, 48, 39, 22, 87, 29684, 89835, 29684, 89835, 29684, 89835, 29684, 89835, 29684, 89835, 29684, 80, 376, 39, 77, 18, 57208, 50536, 47, 16, 62077, 51, 86746, 34, 2465, 89835, 51, 835, 4, 18, 2599, 64087, 19, 47, 16, 71016, 87, 73, 4942, 77, 57, 4991, 57208, 42, 1546, 18023, 19, 87, 73, 15, 5, 10104, 55213, 3524, 4513, 1824, 4080, 25762, 5473, 1337, 1232, 364, 9412, 6075, 518, 364, 2899, 4229, 1232, 364, 1049, 518, 364, 20489, 1232, 364, 4012, 25762,  ...
# [{'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/favicon.ico'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/r/image/2016-02-29/d64d08227f0492df410374cc7372f1dc.jpg'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}]
# Analyzing batch 5/5...
# generations=[[GenerationChunk(text="After analyzing the network packet data, I can detect some suspicious activities.\n\nThe provided data contains two HTTP requests to `www.hao123.com` with different paths: `/favicon.ico` and `/r/image/2016-02-29/d64d08227f0492df410374cc7372f1dc.jpg`. The second request is for an image file, which is a legitimate request. However, the path of this image file seems suspicious.\n\nThe path `/r/image/...jpg` suggests that it might be a URL shortener or a redirect link. In this case, `www.hao123.com` is a Chinese search engine and portal website. It's possible that the second HTTP request is attempting to fetch an image from a malicious server, which could be used for phishing or malware distribution.\n\nThe fact that there are two consecutive requests to the same domain with different paths might indicate some kind of reconnaissance or information gathering activity. However, without more context or additional data, it's difficult to determine the true intent behind these requests.\n\nTo further investigate this suspicious activity, I would recommend:\n\n1. Checking the reputation and trustworthiness of `www.hao123.com`.\n2. Analyzing the image file being requested to see if it contains any malicious code.\n3. Monitoring network traffic for similar patterns or anomalies.\n4. Implementing additional security measures, such as URL filtering or sandboxing, to prevent potential threats.\n\nIn summary, while I cannot confirm with certainty that this is a malicious activity, the suspicious path of the second HTTP request warrants further investigation and caution.", generation_info={'model': 'llama3.1:latest', 'created_at': '2024-12-07T19:30:14.319193Z', 'response': '', 'done': True, 'done_reason': 'stop', 'context': [128006, 882, 128007, 1432, 2675, 527, 264, 62542, 6335, 13, 38527, 3059, 279, 2768, 4009, 10361, 828, 369, 904, 32427, 7640, 323, 10765, 904, 39270, 5540, 13, 1442, 499, 4250, 11388, 904, 39270, 5540, 1243, 2019, 330, 40, 4250, 11388, 904, 39270, 5540, 52518, 58, 13922, 1337, 1232, 364, 9412, 6274, 518, 364, 4492, 1232, 364, 3891, 518, 364, 3875, 1232, 364, 2185, 870, 3524, 4513, 916, 518, 364, 2398, 1232, 3434, 55657, 40286, 25762, 5473, 1337, 1232, 364, 9412, 6075, 518, 364, 2899, 4229, 1232, 364, 1049, 518, 364, 20489, 1232, 364, 4012, 25762, 5473, 1337, 1232, 364, 9412, 6274, 518, 364, 4492, 1232, 364, 3891, 518, 364, 3875, 1232, 364, 2185, 870, 3524, 4513, 916, 518, 364, 2398, 1232, 3434, 81, 24234, 14, 679, 21, 12, 2437, 12, 1682, 3529, 1227, 67, 24996, 1544, 69, 25307, 17, 3013, 14487, 18265, 641, 22039, 17, 69, 16, 7783, 4924, 25762, 5473, 1337, 1232, 364, 9412, 6075, 518, 364, 2899, 4229, 1232, 364, 1049, 518, 364, 20489, 1232, 364, 4012, 8439, 2595, 3957, 1070, 4205, 32427, 30, 1442, 779, 11, 7664, 279, 39270, 5820, 304, 7872, 627, 128009, 128006, 78191, 128007, 271, 6153, 42118, 279, 4009, 10361, 828, 11, 358, 649, 11388, 1063, 32427, 7640, 382, 791, 3984, 828, 5727, 1403, 10339, 7540, 311, 1595, 2185, 870, 3524, 4513, 916, 63, 449, 2204, 13006, 25, 38401, 55657, 40286, 63, 323, 38401, 81, 24234, 14, 679, 21, 12, 2437, 12, 1682, 3529, 1227, 67, 24996, 1544, 69, 25307, 17, 3013, 14487, 18265, 641, 22039, 17, 69, 16, 7783, 4924, 29687, 578, 2132, 1715, 374, 369, 459, 2217, 1052, 11, 902, 374, 264, 23583, 1715, 13, 4452, 11, 279, 1853, 315, 420, 2217, 1052, 5084, 32427, 382, 791, 1853, 38401, 81, 24234, 14, 1131, 18458, 63, 13533, 430, 433, 2643, 387, 264, 5665, 2875, 804, 477, 264, 6559, 2723, 13, 763, 420, 1162, 11, 1595, 2185, 870, 3524, 4513, 916, 63, 374, 264, 8620, 2778, 4817, 323, 24007, 3997, 13, 1102, 596, 3284, 430, 279, 2132, 10339, 1715, 374, 19969, 311, 7963, 459, 2217, 505, 264, 39270, 3622, 11, 902, 1436, 387, 1511, 369, 99197, 477, 40831, 8141, 382, 791, 2144, 430, 1070, 527, 1403, 24871, 7540, 311, 279, 1890, 8106, 449, 2204, 13006, 2643, 13519, 1063, 3169, 315, 88605, 477, 2038, 23738, 5820, 13, 4452, 11, 2085, 810, 2317, 477, 5217, 828, 11, 433, 596, 5107, 311, ...

# %%
for result in results:
    generations = result['response'].__dict__['generations']  # Access generations via __dict__
    text = generations[0][0].text  # Access the text attribute of the first GenerationChunk
    print(text)
# Out:
# After analyzing the network packet data, I have identified a potential malicious element.
#
# The suspicious activity is related to the second HTTP request:
#
# `{'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/?tn=93803173_s_hao_pg'}`
#
# This URL appears to be a redirect URL, which is a common technique used by attackers to bypass security controls. The `tn` parameter in the URL seems to be a tracking number or a token that might be used for malicious purposes.
#
# Upon further investigation, I found that `www.hao123.com` is a Chinese website that has been associated with malware and phishing attacks in the past. This raises concerns about the legitimacy of the redirect URL.
#
# The fact that this request was made after a 302 status code (Moved Temporarily) from `www.02995.com` suggests that there might be a chain of redirects, which can be used to conceal the true destination of the request. This could potentially lead to a malicious website or malware being downloaded onto the victim's device.
#
# Additionally, the presence of a tracking number (`tn=93803173_s_hao_pg`) in the URL could indicate that the attacker is trying to track user activity or steal sensitive information.
#
# In summary, while I cannot confirm with certainty whether this activity is malicious without further context, the combination of suspicious URL parameters and redirects from an unknown website raises significant concerns about potential malicious activity.
# After analyzing the network packet data, I have identified some suspicious activities. Here's a detailed breakdown:
#
# **Malicious Activity 1: Unusual URL Parameters**
#
# The first HTTP request to `www.hao123.com` contains an unusual parameter `tn=93803173_s_hao_pg&_=1456819436683`. The presence of this parameter is suspicious because it appears to be a tracking or analytics token, which is not typically included in a standard GET request. This could indicate that the website is using some form of tracking or monitoring mechanism without user consent.
#
# **Malicious Activity 2: Image Request with Suspicious Parameters**
#
# The third HTTP request to `www.hao123.com` contains an image request (`/images/track.gif`) with several suspicious parameters:
#
# * `level=1`: This parameter suggests that the website is using some form of tracking or monitoring mechanism, which could be used to collect user data.
# * `page=index&type=ua&browser=firefox_41&core=firefox_41&device=na_-1&os=linux_-1&r=1456819438383`: These parameters appear to be collecting information about the user's browser, operating system, and device. This could be used for tracking or profiling purposes.
#
# **Malicious Activity 3: Unusual Image Request**
#
# The second HTTP request to `www.hao123.com` contains an image request (`/v.gif`) with a suspicious parameter `e=AB0_ce01018c62dced37ae0916c9ffb6eff0_0_0_7mgeu6&_=il94ofz1`. The presence of this parameter is unusual and could indicate that the website is using some form of tracking or monitoring mechanism.
#
# **Conclusion**
#
# Based on my analysis, I have identified three suspicious activities:
#
# 1. Unusual URL parameters in the first HTTP request.
# 2. Image requests with suspicious parameters (tracking/monitoring tokens) in the second and third HTTP requests.
# 3. An unusual image request with a suspicious parameter.
#
# These activities could indicate that the website is using some form of tracking or monitoring mechanism without user consent, which raises concerns about user privacy. However, it's essential to note that these findings do not necessarily mean that the website is malicious or intentionally collecting sensitive information. Further investigation and analysis would be required to determine the true nature of these activities.
# After analyzing the network packet data, I have detected some suspicious activities. Here's a detailed description of the malicious elements:
#
# **Malicious Activity 1: Unusual HTTP Request**
#
# The first GET request to `www.hao123.com/api/newforecast` contains a callback parameter with a jQuery-specific callback function (`jQuery17207509154191061225_1456819436527`). This is unusual because it suggests that the client-side JavaScript code is making an AJAX request to this API endpoint, which may be used for tracking or analytics purposes. However, the presence of this callback parameter could also indicate that a malicious script is being executed on the client-side.
#
# **Malicious Activity 2: Tracking GIF Request**
#
# The second GET request to `www.hao123.com/images/track.gif` contains several parameters (`level=1`, `page=index`, `type=KTN`, `code=0`, `tn=&src=&r=1456819439201`) that seem unrelated to the actual content of the track GIF image. These parameters may be used for tracking or analytics purposes, but they could also be used by a malicious script to fingerprint the user's browser or device.
#
# **Malicious Activity 3: Unusual Timing**
#
# The timing between the two GET requests is extremely short (approximately 1 millisecond), which suggests that these requests are being made in rapid succession. This unusual timing pattern may indicate that a malicious script is trying to evade detection by making multiple requests in quick succession.
#
# In summary, while I cannot confirm with certainty whether these activities are malicious or not, the presence of unusual callback parameters, tracking GIF requests, and suspicious timing patterns suggest that there may be some malicious activity occurring. Further analysis would be required to determine the full extent of this potential threat.
# After analyzing the network packet data, I have detected a potential malicious activity. Here's my analysis:
#
# **Suspicious Activity:**
#
# The first HTTP request to `www.hao123.com` contains a query string parameter called `flag=hao123-cpc`. This parameter is not typical of a standard HTTP request and may indicate an attempt to track or fingerprint the user.
#
# Furthermore, the second HTTP request to `www.hao123.com` contains several suspicious parameters:
#
# * `/images/track.gif?level=1&page=index&type=cpc&state=-1&bid=5B7AB1B70A3EEB48F7B3BE4B62FBFDB8&code=cpc_gl_gouwu0&r=1456819441081`
#
# These parameters suggest that the request is attempting to track or monitor user activity, possibly for advertising or analytics purposes. The presence of a unique identifier (`bid`) and a timestamp (`r`) further supports this theory.
#
# **Malicious Elements:**
#
# While not necessarily malicious in nature, these activities could be considered suspicious or unwanted tracking behavior. The use of query string parameters to track user activity is often associated with online advertising or analytics scripts that may compromise user privacy.
#
# In the context of cybersecurity, this activity could be classified as a "tracking" or "fingerprinting" attack, where an attacker attempts to gather information about a user's browsing habits without their consent. However, it's essential to note that this behavior is not necessarily malicious in intent but rather a form of unwanted tracking.
#
# **Recommendation:**
#
# To mitigate this potential issue, users should be aware of the websites they visit and the data they share online. They can also use browser extensions or tools to block or disable tracking scripts like these. Additionally, website administrators should ensure that their websites do not inadvertently enable tracking behavior by including suspicious query string parameters in their HTTP requests.
#
# **Conclusion:**
#
# While I have detected a potential malicious activity, it's essential to note that this behavior is more related to unwanted tracking than an actual cyber attack. However, users and website administrators should remain vigilant and take necessary precautions to protect user privacy and security.
# After analyzing the network packet data, I can detect some suspicious activities.
#
# The provided data contains two HTTP requests to `www.hao123.com` with different paths: `/favicon.ico` and `/r/image/2016-02-29/d64d08227f0492df410374cc7372f1dc.jpg`. The second request is for an image file, which is a legitimate request. However, the path of this image file seems suspicious.
#
# The path `/r/image/...jpg` suggests that it might be a URL shortener or a redirect link. In this case, `www.hao123.com` is a Chinese search engine and portal website. It's possible that the second HTTP request is attempting to fetch an image from a malicious server, which could be used for phishing or malware distribution.
#
# The fact that there are two consecutive requests to the same domain with different paths might indicate some kind of reconnaissance or information gathering activity. However, without more context or additional data, it's difficult to determine the true intent behind these requests.
#
# To further investigate this suspicious activity, I would recommend:
#
# 1. Checking the reputation and trustworthiness of `www.hao123.com`.
# 2. Analyzing the image file being requested to see if it contains any malicious code.
# 3. Monitoring network traffic for similar patterns or anomalies.
# 4. Implementing additional security measures, such as URL filtering or sandboxing, to prevent potential threats.
#
# In summary, while I cannot confirm with certainty that this is a malicious activity, the suspicious path of the second HTTP request warrants further investigation and caution.
