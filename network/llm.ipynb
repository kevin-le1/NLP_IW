# %%
# from langchain_ollama.llms import OllamaLLM
from __init__ import llm
from scapy.all import rdpcap, Raw
from scapy.layers.http import HTTPRequest, HTTPResponse
from scapy.layers.dns import DNSQR, DNSRR
import os

# Function to extract HTTP and DNS data
def extract_data_from_packets(packets):
    extracted_data = []
    for packet in packets:
        # HTTP Request
        if packet.haslayer(HTTPRequest):
            http_layer = packet[HTTPRequest]
            extracted_data.append({
                "type": "HTTP Request",
                "method": http_layer.Method.decode() if http_layer.Method else "",
                "host": http_layer.Host.decode() if http_layer.Host else "",
                "path": http_layer.Path.decode() if http_layer.Path else "",
            })
            
        # HTTP Response
        elif packet.haslayer(HTTPResponse):
            http_layer = packet[HTTPResponse]
            extracted_data.append({
                "type": "HTTP Response",
                "status_code": http_layer.Status_Code.decode() if http_layer.Status_Code else "",
                "reason": http_layer.Reason_Phrase.decode() if http_layer.Reason_Phrase else "",
            })
            
        # DNS Query
        elif packet.haslayer(DNSQR):
            dns_layer = packet[DNSQR]
            extracted_data.append({
                "type": "DNS Query",
                "query_name": dns_layer.qname.decode() if dns_layer.qname else "",
            })
            
        # DNS Response
        elif packet.haslayer(DNSRR):
            dns_layer = packet[DNSRR]
            extracted_data.append({
                "type": "DNS Response",
                "response_name": dns_layer.rrname.decode() if dns_layer.rrname else "",
                "response_data": dns_layer.rdata.decode() if hasattr(dns_layer.rdata, "decode") else dns_layer.rdata,
            })
            
    return extracted_data

# Function to batch the data
def batch_data(data, batch_size):
    for i in range(0, len(data), batch_size):
        yield data[i:i + batch_size]
        
# Function to process each batch for an LLM
def prepare_batch_for_llm(batch):
    llm_input = ""
    for item in batch:
        if item["type"] == "HTTP Request":
            llm_input += f"HTTP Request - Method: {item['method']}, Host: {item['host']}, Path: {item['path']}\n"
        elif item["type"] == "HTTP Response":
            llm_input += f"HTTP Response - Status Code: {item['status_code']}, Reason: {item['reason']}\n"
        elif item["type"] == "DNS Query":
            llm_input += f"DNS Query - Query Name: {item['query_name']}\n"
        elif item["type"] == "DNS Response":
            llm_input += f"DNS Response - Response Name: {item['response_name']}, Response Data: {item['response_data']}\n"
    return llm_input

# Function to query LLM for each batch
def analyze_batch_with_llm(llm, batch_input):
    prompt = f"""
You are a cybersecurity expert. Analyze the following network packet data for any suspicious activities and identify any malicious elements. 
If you cannot detect any malicious elements then say "I cannot detect any malicious elements":

{batch_input}

Is there anything suspicious? If so, describe the malicious activity in detail.
"""
    response = llm.generate([prompt])
    return response


def run(packets):
    # Define the number of batches (5)
    NUM_BATCHES = 5

    # Extract data from the PCAP file
    data = extract_data_from_packets(packets)

    # Calculate the number of packets in each batch
    total_packets = len(data)
    batch_size = total_packets // NUM_BATCHES  # Base size of each batch
    remainder = total_packets % NUM_BATCHES   # Remaining packets to distribute

    # Prepare the batches
    all_batches = []
    start_idx = 0

    for i in range(NUM_BATCHES):
        # Calculate the size of this batch (base size + 1 if remainder > 0)
        end_idx = start_idx + batch_size + (1 if i < remainder else 0)
        batch = data[start_idx:end_idx]
        all_batches.append(batch)

        # Update the starting index for the next batch
        start_idx = end_idx


    # Analyze all batches
    results = []
    for i, batch in enumerate(all_batches):
        
        print(batch)
        print(f"Analyzing batch {i + 1}/{len(all_batches)}...")
        result = analyze_batch_with_llm(llm, batch)
        print(result)
        results.append({"batch": i + 1, "response": result})

    # Print results for each batch
    # for result in results:
    #     print(f"Analysis:\n{result['response']['generations'][0]['text']}\n")

    return results

# %%
results = run(rdpcap("/Users/kevin/Desktop/NLP_IW/network/packet_inject/hao123-com_packet-injection.pcap"))
#results = run(rdpcap("/Users/kevin/Desktop/NLP_IW/network/ddos/amp.UDP.DNSANY.pcap"))
# Out:
# [{'type': 'HTTP Request', 'method': 'GET', 'host': 'www.02995.com', 'path': '/'}, {'type': 'HTTP Response', 'status_code': '302', 'reason': 'Moved Temporarily'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/?tn=93803173_s_hao_pg'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}]
# Analyzing batch 1/5...
# generations=[[ChatGeneration(text='Based on the provided network packet data, there are a few elements that could be considered suspicious:\n\n1. **Unusual Hostnames**: The first HTTP request is made to `www.02995.com`, which is not a well-known or reputable domain. This could indicate that the request is targeting a potentially malicious or compromised site. The domain does not appear to be associated with any legitimate service, which raises a red flag.\n\n2. **Redirect Response**: The second packet shows an HTTP response with a status code of `302` (Moved Temporarily). This indicates that the initial request to `www.02995.com` was redirected. While redirects are common in web traffic, they can also be used maliciously to lead users to phishing sites or to serve malicious content. The destination of the redirect is not provided, which makes it difficult to assess the safety of the subsequent request.\n\n3. **Subsequent Request to Hao123**: The next HTTP request is made to `www.hao123.com`, which is a known website that aggregates links and services. However, the query parameter `tn=93803173_s_hao_pg` could be indicative of tracking or ad-related behavior. While this alone is not necessarily malicious, it could suggest that the user is being tracked or redirected through various sites, which is a common tactic in ad fraud or click fraud schemes.\n\n4. **Multiple HTTP Responses**: The presence of multiple HTTP responses with status code `200` (OK) following the request to `hao123.com` suggests that the connection is functioning normally, but without additional context, it is unclear what content is being served. If the content served is malicious or if it is part of a larger chain of redirects, this could be a concern.\n\nIn summary, while there are no definitive indicators of malicious activity, the combination of an unusual initial request, a redirect response, and the tracking parameters in the subsequent request raises concerns about potential phishing, ad fraud, or other malicious activities. Further investigation into the domains and the content being served would be necessary to confirm any malicious intent.\n\n**Conclusion**: There are suspicious elements present, particularly regarding the initial request to an unusual domain and the subsequent redirect. Further analysis is warranted to determine the full context and potential risks.', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='Based on the provided network packet data, there are a few elements that could be considered suspicious:\n\n1. **Unusual Hostnames**: The first HTTP request is made to `www.02995.com`, which is not a well-known or reputable domain. This could indicate that the request is targeting a potentially malicious or compromised site. The domain does not appear to be associated with any legitimate service, which raises a red flag.\n\n2. **Redirect Response**: The second packet shows an HTTP response with a status code of `302` (Moved Temporarily). This indicates that the initial request to `www.02995.com` was redirected. While redirects are common in web traffic, they can also be used maliciously to lead users to phishing sites or to serve malicious content. The destination of the redirect is not provided, which makes it difficult to assess the safety of the subsequent request.\n\n3. **Subsequent Request to Hao123**: The next HTTP request is made to `www.hao123.com`, which is a known website that aggregates links and services. However, the query parameter `tn=93803173_s_hao_pg` could be indicative of tracking or ad-related behavior. While this alone is not necessarily malicious, it could suggest that the user is being tracked or redirected through various sites, which is a common tactic in ad fraud or click fraud schemes.\n\n4. **Multiple HTTP Responses**: The presence of multiple HTTP responses with status code `200` (OK) following the request to `hao123.com` suggests that the connection is functioning normal ...
# [{'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/api/tnwhilte?tn=93803173_s_hao_pg&_=1456819436683'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/v.gif?e=AB0_ce01018c62dced37ae0916c9ffb6eff0_0_0_7mgeu6&_=il94ofz1'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/images/track.gif?level=1&page=index&type=ua&browser=firefox_41&core=firefox_41&device=na_-1&os=linux_-1&r=1456819438383'}]
# Analyzing batch 2/5...
# generations=[[ChatGeneration(text='Based on the provided network packet data, I cannot detect any malicious elements. The requests appear to be standard HTTP GET requests to a known website (www.hao123.com) and do not exhibit any obvious signs of malicious activity such as unusual payloads, suspicious URLs, or abnormal behavior patterns. The responses indicate successful retrieval of resources with a status code of 200 (OK). \n\nIf you have more specific criteria for identifying suspicious activities or additional data to analyze, please provide that information for a more detailed assessment.', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='Based on the provided network packet data, I cannot detect any malicious elements. The requests appear to be standard HTTP GET requests to a known website (www.hao123.com) and do not exhibit any obvious signs of malicious activity such as unusual payloads, suspicious URLs, or abnormal behavior patterns. The responses indicate successful retrieval of resources with a status code of 200 (OK). \n\nIf you have more specific criteria for identifying suspicious activities or additional data to analyze, please provide that information for a more detailed assessment.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 104, 'prompt_tokens': 299, 'total_tokens': 403, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-eef698e4-48d5-4546-b5d7-05ebd61018a5-0', usage_metadata={'input_tokens': 299, 'output_tokens': 104, 'total_tokens': 403}))]] llm_output={'token_usage': {'completion_tokens': 104, 'prompt_tokens': 299, 'total_tokens': 403, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini', 'system_fingerprint': 'fp_0aa8d3e20b'} run=[RunInfo(run_id=UUID('eef698e4-48d5-4546-b5d7-05ebd61018a5'))]
# [{'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/api/newforecast?callback=jQuery17207509154191061225_1456819436527&t=1&_=1456819438720'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/images/track.gif?level=1&page=index&type=KTN&code=0&tn=&src=&r=1456819439201'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}]
# Analyzing batch 3/5...
# generations=[[ChatGeneration(text='Based on the provided network packet data, I cannot detect any malicious elements. The HTTP requests and responses indicate normal web traffic, with status codes of 200 (OK) suggesting successful interactions with the server. The requests appear to be fetching resources from the specified host, and there are no indications of unusual patterns, such as suspicious payloads, unexpected methods, or known malicious endpoints. \n\nIf you have more specific details or additional data, I could provide a more thorough analysis.', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='Based on the provided network packet data, I cannot detect any malicious elements. The HTTP requests and responses indicate normal web traffic, with status codes of 200 (OK) suggesting successful interactions with the server. The requests appear to be fetching resources from the specified host, and there are no indications of unusual patterns, such as suspicious payloads, unexpected methods, or known malicious endpoints. \n\nIf you have more specific details or additional data, I could provide a more thorough analysis.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 96, 'prompt_tokens': 241, 'total_tokens': 337, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-1a1db8d6-2e63-4193-a1e4-82639804a322-0', usage_metadata={'input_tokens': 241, 'output_tokens': 96, 'total_tokens': 337}))]] llm_output={'token_usage': {'completion_tokens': 96, 'prompt_tokens': 241, 'total_tokens': 337, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini', 'system_fingerprint': 'fp_0aa8d3e20b'} run=[RunInfo(run_id=UUID('1a1db8d6-2e63-4193-a1e4-82639804a322'))]
# [{'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/v.gif?c=f%2Cf503a8d7.PHubPHwWuW0znjNbnWRYuHI9P1-WmH79xjDYPHm3nHbYPjKtxjT4QWDsnB3zPjb8n1Ktn1-trjbYxAPYT-qk5HTsnakWTAdxTHYknakWIZFxIZFb5HnsQANzpgP-u7qVUvwdUARqnBkEIgw-T-q-XZKxIA7M5iktQH7xQH7xQH7xQH7xQHDoQH7xgdqxgdqxgdqxgdqxgdqxgdqtrHn3njnkP1PxTdqCmyqxTAT%3APjc4P1DYxjcsnZsknjKtnWD4xj0&flag=hao123-cpc'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/images/track.gif?level=1&page=index&type=cpc&state=-1&bid=5B7AB1B70A3EEB48F7B3BE4B62FBFDB8&code=cpc_gl_gouwu0&r=1456819441081'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}]
# Analyzing batch 4/5...
# generations=[[ChatGeneration(text='Based on the provided network packet data, I cannot detect any malicious elements. The HTTP requests appear to be standard GET requests to a known website (www.hao123.com) and the responses indicate successful retrieval of resources (status code 200). The parameters in the requests, while lengthy and complex, do not inherently indicate malicious activity without further context or additional indicators of compromise. \n\nIf you have more specific details or additional data, I could provide a more thorough analysis.', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='Based on the provided network packet data, I cannot detect any malicious elements. The HTTP requests appear to be standard GET requests to a known website (www.hao123.com) and the responses indicate successful retrieval of resources (status code 200). The parameters in the requests, while lengthy and complex, do not inherently indicate malicious activity without further context or additional indicators of compromise. \n\nIf you have more specific details or additional data, I could provide a more thorough analysis.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 95, 'prompt_tokens': 419, 'total_tokens': 514, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-cb5423bf-8ffe-4dcd-9ecd-40c1ab2bb333-0', usage_metadata={'input_tokens': 419, 'output_tokens': 95, 'total_tokens': 514}))]] llm_output={'token_usage': {'completion_tokens': 95, 'prompt_tokens': 419, 'total_tokens': 514, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini', 'system_fingerprint': 'fp_0aa8d3e20b'} run=[RunInfo(run_id=UUID('cb5423bf-8ffe-4dcd-9ecd-40c1ab2bb333'))]
# [{'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/favicon.ico'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}, {'type': 'HTTP Request', 'method': 'GET', 'host': 'www.hao123.com', 'path': '/r/image/2016-02-29/d64d08227f0492df410374cc7372f1dc.jpg'}, {'type': 'HTTP Response', 'status_code': '200', 'reason': 'OK'}]
# Analyzing batch 5/5...
# generations=[[ChatGeneration(text='I cannot detect any malicious elements.', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='I cannot detect any malicious elements.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 190, 'total_tokens': 198, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-80065831-1693-4cb9-bfae-ac098af55a84-0', usage_metadata={'input_tokens': 190, 'output_tokens': 8, 'total_tokens': 198}))]] llm_output={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 190, 'total_tokens': 198, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini', 'system_fingerprint': 'fp_0aa8d3e20b'} run=[RunInfo(run_id=UUID('80065831-1693-4cb9-bfae-ac098af55a84'))]

# %%
for result in results:
    generations = result['response'].__dict__['generations']  # Access generations via __dict__
    text = generations[0][0].text  # Access the text attribute of the first GenerationChunk
    print(text)
# Out:
# Based on the provided network packet data, there are a few elements that could be considered suspicious:
#
# 1. **Unusual Hostnames**: The first HTTP request is made to `www.02995.com`, which is not a well-known or reputable domain. This could indicate that the request is targeting a potentially malicious or compromised site. The domain does not appear to be associated with any legitimate service, which raises a red flag.
#
# 2. **Redirect Response**: The second packet shows an HTTP response with a status code of `302` (Moved Temporarily). This indicates that the initial request to `www.02995.com` was redirected. While redirects are common in web traffic, they can also be used maliciously to lead users to phishing sites or to serve malicious content. The destination of the redirect is not provided, which makes it difficult to assess the safety of the subsequent request.
#
# 3. **Subsequent Request to Hao123**: The next HTTP request is made to `www.hao123.com`, which is a known website that aggregates links and services. However, the query parameter `tn=93803173_s_hao_pg` could be indicative of tracking or ad-related behavior. While this alone is not necessarily malicious, it could suggest that the user is being tracked or redirected through various sites, which is a common tactic in ad fraud or click fraud schemes.
#
# 4. **Multiple HTTP Responses**: The presence of multiple HTTP responses with status code `200` (OK) following the request to `hao123.com` suggests that the connection is functioning normally, but without additional context, it is unclear what content is being served. If the content served is malicious or if it is part of a larger chain of redirects, this could be a concern.
#
# In summary, while there are no definitive indicators of malicious activity, the combination of an unusual initial request, a redirect response, and the tracking parameters in the subsequent request raises concerns about potential phishing, ad fraud, or other malicious activities. Further investigation into the domains and the content being served would be necessary to confirm any malicious intent.
#
# **Conclusion**: There are suspicious elements present, particularly regarding the initial request to an unusual domain and the subsequent redirect. Further analysis is warranted to determine the full context and potential risks.
# Based on the provided network packet data, I cannot detect any malicious elements. The requests appear to be standard HTTP GET requests to a known website (www.hao123.com) and do not exhibit any obvious signs of malicious activity such as unusual payloads, suspicious URLs, or abnormal behavior patterns. The responses indicate successful retrieval of resources with a status code of 200 (OK).
#
# If you have more specific criteria for identifying suspicious activities or additional data to analyze, please provide that information for a more detailed assessment.
# Based on the provided network packet data, I cannot detect any malicious elements. The HTTP requests and responses indicate normal web traffic, with status codes of 200 (OK) suggesting successful interactions with the server. The requests appear to be fetching resources from the specified host, and there are no indications of unusual patterns, such as suspicious payloads, unexpected methods, or known malicious endpoints.
#
# If you have more specific details or additional data, I could provide a more thorough analysis.
# Based on the provided network packet data, I cannot detect any malicious elements. The HTTP requests appear to be standard GET requests to a known website (www.hao123.com) and the responses indicate successful retrieval of resources (status code 200). The parameters in the requests, while lengthy and complex, do not inherently indicate malicious activity without further context or additional indicators of compromise.
#
# If you have more specific details or additional data, I could provide a more thorough analysis.
# I cannot detect any malicious elements.
