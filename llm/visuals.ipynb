# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import pandas as pd

# %%
df = pd.read_csv("predictions.csv")

sns.heatmap(confusion_matrix(df['y_true'], df['y_pred']), annot=True, cmap='RdYlGn_r', annot_kws={'size': 16})
# Out:
# <Axes: >
